# %%
# !pip install pulp
from pulp import *
# Out:
# Requirement already satisfied: pulp in c:\users\chris\.julia\conda\3\lib\site-packages (1.6.10)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\chris\.julia\conda\3\lib\site-packages (from pulp) (2.4.5)

# %%
# Creates a list of the scenarios
scenarios = ['MEDIUM', 'HIGH', 'LOW']
crops = ['Corn', 'Sugar Beets','Wheat']
products = ['Corn', 'Sugar Beets HighProfit', 'Sugar Beets LowProfit', 'Wheat']

# Dictionaries with data
yields = {'Wheat': 2.5, 
         'Corn': 3,
         'Sugar Beets': 20}

productCropMapping = {'Wheat': 'Wheat', 
         'Corn': 'Corn',
         'Sugar Beets HighProfit': 'Sugar Beets',
         'Sugar Beets LowProfit': 'Sugar Beets'}

maxSale = {'Wheat': -1, 
         'Corn': -1,
         'Sugar Beets HighProfit': 6000,
         'Sugar Beets LowProfit': -1
}

yieldModifier = {'HIGH': 1.2, 
         'MEDIUM': 1,
         'LOW': 0.8}

plantingCost = {'Wheat': 150, 
         'Corn': 230,
         'Sugar Beets': 260}
    
salesPrice = {'Wheat': 170, 
         'Corn': 150,
         'Sugar Beets HighProfit': 36,
         'Sugar Beets LowProfit': 10}
    
purchasePrice =  {'Wheat': 238, 
         'Corn': 210,
         'Sugar Beets': 99999}
    
requirements = {'Wheat': 200, 
         'Corn': 240,
            'Sugar Beets': 0}

# A dictionary of the probability of each scenario
probability = {'HIGH': 1/3, 
         'MEDIUM': 1/3,
         'LOW': 1/3}

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Farmer Problem", LpMaximize)


# Create decision variables
plant = LpVariable.dicts("Planting",crops,0) # non-recourse variable
sales = LpVariable.dicts("Period Sales",list(itertools.product(products,scenarios)),0) # recourse variables
purchase = LpVariable.dicts("Purchase",list(itertools.product(crops,scenarios,)),0) # recourse variables

# Create objective function
prob += lpSum([probability[i]*lpSum([sales[j,i]*salesPrice[j] for j in products]) - probability[i]*lpSum([purchase[j,i]*purchasePrice[j] for j in purchasePrice.keys()]) for i in scenarios]) - lpSum([plant[i] * plantingCost[i] for i in crops])

prob += lpSum(plant[i] for i in crops) <= 500

for i in scenarios:
    for j in crops:
        # Inventory constraint
        prob += yieldModifier[i]*yields[j]*plant[j]+purchase[j,i] - lpSum(sales[p,i] for p in products if productCropMapping[p]==j) >= requirements[j], "Feed %s %s" %(i,j)
    for j in products:
        if maxSale[j]>=0:
            prob += sales[j,i]<=maxSale[j], "Sales Limit %s %s" %(j,i)

# %%
print(prob)
# Out:
# Farmer Problem:
# MAXIMIZE
# 50.0*Period_Sales_('Corn',_'HIGH') + 50.0*Period_Sales_('Corn',_'LOW') + 50.0*Period_Sales_('Corn',_'MEDIUM') + 12.0*Period_Sales_('Sugar_Beets_HighProfit',_'HIGH') + 12.0*Period_Sales_('Sugar_Beets_HighProfit',_'LOW') + 12.0*Period_Sales_('Sugar_Beets_HighProfit',_'MEDIUM') + 3.333333333333333*Period_Sales_('Sugar_Beets_LowProfit',_'HIGH') + 3.333333333333333*Period_Sales_('Sugar_Beets_LowProfit',_'LOW') + 3.333333333333333*Period_Sales_('Sugar_Beets_LowProfit',_'MEDIUM') + 56.666666666666664*Period_Sales_('Wheat',_'HIGH') + 56.666666666666664*Period_Sales_('Wheat',_'LOW') + 56.666666666666664*Period_Sales_('Wheat',_'MEDIUM') + -230*Planting_Corn + -260*Planting_Sugar_Beets + -150*Planting_Wheat + -70.0*Purchase_('Corn',_'HIGH') + -70.0*Purchase_('Corn',_'LOW') + -70.0*Purchase_('Corn',_'MEDIUM') + -33333.0*Purchase_('Sugar_Beets',_'HIGH') + -33333.0*Purchase_('Sugar_Beets',_'LOW') + -33333.0*Purchase_('Sugar_Beets',_'MEDIUM') + -79.33333333333333*Purchase_('Wheat',_'HIGH') + -79.33333333333333*Purchase_('Wheat',_'LOW') + -79.33333333333333*Purchase_('Wheat',_'MEDIUM') + 0.0
# SUBJECT TO
# _C1: Planting_Corn + Planting_Sugar_Beets + Planting_Wheat <= 500
#
# Feed_MEDIUM_Corn: - Period_Sales_('Corn',_'MEDIUM') + 3 Planting_Corn
#  + Purchase_('Corn',_'MEDIUM') >= 240
#
# Feed_MEDIUM_Sugar_Beets: - Period_Sales_('Sugar_Beets_HighProfit',_'MEDIUM')
#  - Period_Sales_('Sugar_Beets_LowProfit',_'MEDIUM') + 20 Planting_Sugar_Beets
#  + Purchase_('Sugar_Beets',_'MEDIUM') >= 0
#
# Feed_MEDIUM_Wheat: - Period_Sales_('Wheat',_'MEDIUM') + 2.5 Planting_Wheat
#  + Purchase_('Wheat',_'MEDIUM') >= 200
#
# Sales_Limit_Sugar_Beets_HighProfit_MEDIUM:
#  Period_Sales_('Sugar_Beets_HighProfit',_'MEDIUM') <= 6000
#
# Feed_HIGH_Corn: - Period_Sales_('Corn',_'HIGH') + 3.6 Planting_Corn
#  + Purchase_('Corn',_'HIGH') >= 240
#
# Feed_HIGH_Sugar_Beets: - Period_Sales_('Sugar_Beets_HighProfit',_'HIGH')
#  - Period_Sales_('Sugar_Beets_LowProfit',_'HIGH') + 24 Planting_Sugar_Beets
#  + Purchase_('Sugar_Beets',_'HIGH') >= 0
#
# Feed_HIGH_Wheat: - Period_Sales_('Wheat',_'HIGH') + 3 Planting_Wheat
#  + Purchase_('Wheat',_'HIGH') >= 200
#
# Sales_Limit_Sugar_Beets_HighProfit_HIGH:
#  Period_Sales_('Sugar_Beets_HighProfit',_'HIGH') <= 6000
#
# Feed_LOW_Corn: - Period_Sales_('Corn',_'LOW') + 2.4 Planting_Corn
#  + Purchase_('Corn',_'LOW') >= 240
#
# Feed_LOW_Sugar_Beets: - Period_Sales_('Sugar_Beets_HighProfit',_'LOW')
#  - Period_Sales_('Sugar_Beets_LowProfit',_'LOW') + 16 Planting_Sugar_Beets
#  + Purchase_('Sugar_Beets',_'LOW') >= 0
#
# Feed_LOW_Wheat: - Period_Sales_('Wheat',_'LOW') + 2 Planting_Wheat
#  + Purchase_('Wheat',_'LOW') >= 200
#
# Sales_Limit_Sugar_Beets_HighProfit_LOW:
#  Period_Sales_('Sugar_Beets_HighProfit',_'LOW') <= 6000
#
# VARIABLES
# Period_Sales_('Corn',_'HIGH') Continuous
# Period_Sales_('Corn',_'LOW') Continuous
# Period_Sales_('Corn',_'MEDIUM') Continuous
# Period_Sales_('Sugar_Beets_HighProfit',_'HIGH') Continuous
# Period_Sales_('Sugar_Beets_HighProfit',_'LOW') Continuous
# Period_Sales_('Sugar_Beets_HighProfit',_'MEDIUM') Continuous
# Period_Sales_('Sugar_Beets_LowProfit',_'HIGH') Continuous
# Period_Sales_('Sugar_Beets_LowProfit',_'LOW') Continuous
# Period_Sales_('Sugar_Beets_LowProfit',_'MEDIUM') Continuous
# Period_Sales_('Wheat',_'HIGH') Continuous
# Period_Sales_('Wheat',_'LOW') Continuous
# Period_Sales_('Wheat',_'MEDIUM') Continuous
# Planting_Corn Continuous
# Planting_Sugar_Beets Continuous
# Planting_Wheat Continuous
# Purchase_('Corn',_'HIGH') Continuous
# Purchase_('Corn',_'LOW') Continuous
# Purchase_('Corn',_'MEDIUM') Continuous
# Purchase_('Sugar_Beets',_'HIGH') Continuous
# Purchase_('Sugar_Beets',_'LOW') Continuous
# Purchase_('Sugar_Beets',_'MEDIUM') Continuous
# Purchase_('Wheat',_'HIGH') Continuous
# Purchase_('Wheat',_'LOW') Continuous
# Purchase_('Wheat',_'MEDIUM') Continuous

# %%
# Optimize

prob.solve()



# Print the status of the solved LP
print("Status = %s" % LpStatus[prob.status])
# Print the value of the objective
print("Objective = %f" % value(prob.objective))


# Print the value of the variables at the optimum
for c in crops:
    print("%s = %f" % (plant[c].name, plant[c].varValue))

for j in sales.keys():
    print("%s %s" %(sales[j].name,sales[j].varValue))
    
for j in purchase.keys():
    if purchasePrice[j[0]] < 1000:
        print("%s %s" %(purchase[j].name,purchase[j].varValue))

    
stochasticObjective = value(prob.objective)
# Out:
# Status = Optimal
# Objective = 108390.000000
# Planting_Corn = 80.000000
# Planting_Sugar_Beets = 250.000000
# Planting_Wheat = 170.000000
# Period_Sales_('Corn',_'MEDIUM') 0.0
# Period_Sales_('Corn',_'HIGH') 48.0
# Period_Sales_('Corn',_'LOW') 0.0
# Period_Sales_('Sugar_Beets_HighProfit',_'MEDIUM') 5000.0
# Period_Sales_('Sugar_Beets_HighProfit',_'HIGH') 6000.0
# Period_Sales_('Sugar_Beets_HighProfit',_'LOW') 4000.0
# Period_Sales_('Sugar_Beets_LowProfit',_'MEDIUM') 0.0
# Period_Sales_('Sugar_Beets_LowProfit',_'HIGH') 0.0
# Period_Sales_('Sugar_Beets_LowProfit',_'LOW') 0.0
# Period_Sales_('Wheat',_'MEDIUM') 225.0
# Period_Sales_('Wheat',_'HIGH') 310.0
# Period_Sales_('Wheat',_'LOW') 140.0
# Purchase_('Corn',_'MEDIUM') 0.0
# Purchase_('Corn',_'HIGH') 0.0
# Purchase_('Corn',_'LOW') 48.0
# Purchase_('Wheat',_'MEDIUM') 0.0
# Purchase_('Wheat',_'HIGH') 0.0
# Purchase_('Wheat',_'LOW') 0.0

# %%
### Determine EVPI


# Creates a list of the scenarios
scenarios = ['MEDIUM', 'HIGH', 'LOW']
crops = ['Corn', 'Sugar Beets','Wheat']
products = ['Corn', 'Sugar Beets HighProfit', 'Sugar Beets LowProfit', 'Wheat']

# Dictionaries with data
yields = {'Wheat': 2.5, 
         'Corn': 3,
         'Sugar Beets': 20}

productCropMapping = {'Wheat': 'Wheat', 
         'Corn': 'Corn',
         'Sugar Beets HighProfit': 'Sugar Beets',
         'Sugar Beets LowProfit': 'Sugar Beets'}

maxSale = {'Wheat': -1, 
         'Corn': -1,
         'Sugar Beets HighProfit': 6000,
         'Sugar Beets LowProfit': -1
}

yieldModifier = {'HIGH': 1.2, 
         'MEDIUM': 1,
         'LOW': 0.8}

plantingCost = {'Wheat': 150, 
         'Corn': 230,
         'Sugar Beets': 260}
    
salesPrice = {'Wheat': 170, 
         'Corn': 150,
         'Sugar Beets HighProfit': 36,
         'Sugar Beets LowProfit': 10}
    
purchasePrice =  {'Wheat': 238, 
         'Corn': 210,
         'Sugar Beets': 99999}
    
requirements = {'Wheat': 200, 
         'Corn': 240,
            'Sugar Beets': 0}

# A dictionary of the probability of each scenario
probability = {'HIGH': 1/3, 
         'MEDIUM': 1/3,
         'LOW': 1/3}

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Farmer Problem", LpMaximize)


# Create decision variables
plant = LpVariable.dicts("Planting",list(itertools.product(crops,scenarios)),0) # non-recourse variable
sales = LpVariable.dicts("Period Sales",list(itertools.product(products,scenarios)),0) # recourse variables
purchase = LpVariable.dicts("Purchase",list(itertools.product(crops,scenarios,)),0) # recourse variables

# Create objective function
prob += lpSum([probability[i]*lpSum([sales[j,i]*salesPrice[j] for j in products]) - probability[i]*lpSum([purchase[j,i]*purchasePrice[j] for j in purchasePrice.keys()]) - probability[i]*lpSum([plant[j,i] * plantingCost[j] for j in crops]) for i in scenarios])


for i in scenarios:
    prob += lpSum(plant[j, i] for j in crops) <= 500
    for j in crops:
        # Inventory constraint
        prob += yieldModifier[i]*yields[j]*plant[j,i]+purchase[j,i] - lpSum(sales[p,i] for p in products if productCropMapping[p]==j) >= requirements[j], "Feed %s %s" %(i,j)
    for j in products:
        if maxSale[j]>=0:
            prob += sales[j,i]<=maxSale[j], "Sales Limit %s %s" %(j,i)
        
# Optimize

prob.solve()



# Print the status of the solved LP
print("Status = %s" % LpStatus[prob.status])
# Print the value of the objective
print("Objective = %f" % value(prob.objective))


# Print the value of the variables at the optimum
for c in plant.keys():
    print("%s = %f" % (plant[c].name, plant[c].varValue))

for j in sales.keys():
    print("%s %s" %(sales[j].name,sales[j].varValue))
    
for j in purchase.keys():
    if purchasePrice[j[0]] < 1000:
        print("%s %s" %(purchase[j].name,purchase[j].varValue))
        
foresightObjective = value(prob.objective)
EVPI = foresightObjective - stochasticObjective
print(EVPI)
# Out:
# Status = Optimal
# Objective = 115405.555697
# Planting_('Corn',_'MEDIUM') = 80.000000
# Planting_('Corn',_'HIGH') = 66.666667
# Planting_('Corn',_'LOW') = 25.000000
# Planting_('Sugar_Beets',_'MEDIUM') = 300.000000
# Planting_('Sugar_Beets',_'HIGH') = 250.000000
# Planting_('Sugar_Beets',_'LOW') = 375.000000
# Planting_('Wheat',_'MEDIUM') = 120.000000
# Planting_('Wheat',_'HIGH') = 183.333330
# Planting_('Wheat',_'LOW') = 100.000000
# Period_Sales_('Corn',_'MEDIUM') 0.0
# Period_Sales_('Corn',_'HIGH') 0.0
# Period_Sales_('Corn',_'LOW') 0.0
# Period_Sales_('Sugar_Beets_HighProfit',_'MEDIUM') 6000.0
# Period_Sales_('Sugar_Beets_HighProfit',_'HIGH') 6000.0
# Period_Sales_('Sugar_Beets_HighProfit',_'LOW') 6000.0
# Period_Sales_('Sugar_Beets_LowProfit',_'MEDIUM') 0.0
# Period_Sales_('Sugar_Beets_LowProfit',_'HIGH') 0.0
# Period_Sales_('Sugar_Beets_LowProfit',_'LOW') 0.0
# Period_Sales_('Wheat',_'MEDIUM') 100.0
# Period_Sales_('Wheat',_'HIGH') 350.0
# Period_Sales_('Wheat',_'LOW') 0.0
# Purchase_('Corn',_'MEDIUM') 0.0
# Purchase_('Corn',_'HIGH') 0.0
# Purchase_('Corn',_'LOW') 180.0
# Purchase_('Wheat',_'MEDIUM') 0.0
# Purchase_('Wheat',_'HIGH') 0.0
# Purchase_('Wheat',_'LOW') 0.0
# 7015.555696666706

# %%
# Creates a list of the scenarios
scenarios = ['MEDIUM', 'HIGH', 'LOW']
crops = ['Corn', 'Sugar Beets','Wheat']
products = ['Corn', 'Sugar Beets HighProfit', 'Sugar Beets LowProfit', 'Wheat']

# Dictionaries with data
yields = {'Wheat': 2.5, 
         'Corn': 3,
         'Sugar Beets': 20}

productCropMapping = {'Wheat': 'Wheat', 
         'Corn': 'Corn',
         'Sugar Beets HighProfit': 'Sugar Beets',
         'Sugar Beets LowProfit': 'Sugar Beets'}

maxSale = {'Wheat': -1, 
         'Corn': -1,
         'Sugar Beets HighProfit': 6000,
         'Sugar Beets LowProfit': -1
}

yieldModifier = {'HIGH': 1.2, 
         'MEDIUM': 1,
         'LOW': 0.8}

plantingCost = {'Wheat': 150, 
         'Corn': 230,
         'Sugar Beets': 260}
    
salesPrice = {'Wheat': 170, 
         'Corn': 150,
         'Sugar Beets HighProfit': 36,
         'Sugar Beets LowProfit': 10}
    
purchasePrice =  {'Wheat': 238, 
         'Corn': 210,
         'Sugar Beets': 99999}
    
requirements = {'Wheat': 200, 
         'Corn': 240,
            'Sugar Beets': 0}

# A dictionary of the probability of each scenario
probability = {'HIGH': 0, 
         'MEDIUM': 1,
         'LOW': 0}

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Farmer Problem", LpMaximize)


# Create decision variables
plant = LpVariable.dicts("Planting",crops,0) # non-recourse variable
sales = LpVariable.dicts("Period Sales",list(itertools.product(products,scenarios)),0) # recourse variables
purchase = LpVariable.dicts("Purchase",list(itertools.product(crops,scenarios,)),0) # recourse variables

# Create objective function
prob += lpSum([probability[i]*lpSum([sales[j,i]*salesPrice[j] for j in products]) - probability[i]*lpSum([purchase[j,i]*purchasePrice[j] for j in purchasePrice.keys()]) for i in scenarios]) - lpSum([plant[i] * plantingCost[i] for i in crops])

prob += lpSum(plant[i] for i in crops) <= 500

for i in scenarios:
    for j in crops:
        # Inventory constraint
        prob += yieldModifier[i]*yields[j]*plant[j]+purchase[j,i] - lpSum(sales[p,i] for p in products if productCropMapping[p]==j) >= requirements[j], "Feed %s %s" %(i,j)
    for j in products:
        if maxSale[j]>=0:
            prob += sales[j,i]<=maxSale[j], "Sales Limit %s %s" %(j,i)
        
# Optimize

prob.solve()



# Print the status of the solved LP
print("Status = %s" % LpStatus[prob.status])

# Print the value of the variables at the optimum

averagePlanting = {}

for c in plant.keys():
    print("%s = %f" % (plant[c].name, plant[c].varValue))
    averagePlanting[c] = plant[c].varValue


# Creates a list of the scenarios
scenarios = ['MEDIUM', 'HIGH', 'LOW']
crops = ['Corn', 'Sugar Beets','Wheat']
products = ['Corn', 'Sugar Beets HighProfit', 'Sugar Beets LowProfit', 'Wheat']

# Dictionaries with data
yields = {'Wheat': 2.5, 
         'Corn': 3,
         'Sugar Beets': 20}

productCropMapping = {'Wheat': 'Wheat', 
         'Corn': 'Corn',
         'Sugar Beets HighProfit': 'Sugar Beets',
         'Sugar Beets LowProfit': 'Sugar Beets'}

maxSale = {'Wheat': -1, 
         'Corn': -1,
         'Sugar Beets HighProfit': 6000,
         'Sugar Beets LowProfit': -1
}

yieldModifier = {'HIGH': 1.2, 
         'MEDIUM': 1,
         'LOW': 0.8}

plantingCost = {'Wheat': 150, 
         'Corn': 230,
         'Sugar Beets': 260}
    
salesPrice = {'Wheat': 170, 
         'Corn': 150,
         'Sugar Beets HighProfit': 36,
         'Sugar Beets LowProfit': 10}
    
purchasePrice =  {'Wheat': 238, 
         'Corn': 210,
         'Sugar Beets': 99999}
    
requirements = {'Wheat': 200, 
         'Corn': 240,
            'Sugar Beets': 0}

# A dictionary of the probability of each scenario
probability = {'HIGH': 1/3, 
         'MEDIUM': 1/3,
         'LOW': 1/3}

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Farmer Problem", LpMaximize)


# Create decision variables
plant = LpVariable.dicts("Planting",crops,0) # non-recourse variable
sales = LpVariable.dicts("Period Sales",list(itertools.product(products,scenarios)),0) # recourse variables
purchase = LpVariable.dicts("Purchase",list(itertools.product(crops,scenarios,)),0) # recourse variables

# Create objective function
prob += lpSum([probability[i]*lpSum([sales[j,i]*salesPrice[j] for j in products]) - probability[i]*lpSum([purchase[j,i]*purchasePrice[j] for j in purchasePrice.keys()]) for i in scenarios]) - lpSum([plant[i] * plantingCost[i] for i in crops])

prob += lpSum(plant[i] for i in crops) <= 500

for i in crops:
    prob += plant[i]==averagePlanting[i] 

for i in scenarios:
    for j in crops:
        # Inventory constraint
        prob += yieldModifier[i]*yields[j]*plant[j]+purchase[j,i] - lpSum(sales[p,i] for p in products if productCropMapping[p]==j) >= requirements[j], "Feed %s %s" %(i,j)
    for j in products:
        if maxSale[j]>=0:
            prob += sales[j,i]<=maxSale[j], "Sales Limit %s %s" %(j,i)
        
prob.solve()
        
naiveObjective = value(prob.objective)
VSS = stochasticObjective - naiveObjective
print(VSS)
# Out:
# Status = Optimal
# Planting_Corn = 80.000000
# Planting_Sugar_Beets = 300.000000
# Planting_Wheat = 120.000000
# 1149.999999999971

# %%
averagePlanting
# Out:
# {'Corn': 80.0, 'Sugar Beets': 300.0, 'Wheat': 120.0}
